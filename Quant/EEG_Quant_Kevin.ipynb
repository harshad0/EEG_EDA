# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('KevinQuant.csv')

# %%
def calc_duration(n):
    '''
    Converts miliseconds to minutes
    '''
    return n/(1000*60)

# %%
#dropping unnecessary columns
data = data.drop(['poorSignal', 'blinkStrength', 'tagEvent', 'location'], axis = 1)

#Shifting timestamp
temp = data['timestampMs'][0]
for i in range(len(data)):
    data.at[i, 'timestampMs'] -= temp #Remember this functionality of dataframe

print(calc_duration(data.iloc[len(data)-1][0]), 'minutes')
data.head()
# Out:
# 58.57608333333334 minutes
#    timestampMs  eegRawValue  eegRawValueVolts  attention  meditation  delta  \
# 0            0            3      6.591797e-07         74          57  27181
# 1           17           26      5.712891e-06         74          57  27181
# 2           33           36      7.910156e-06         74          57  27181
# 3           50           84      1.845703e-05         74          57  27181
# 4           67           58      1.274414e-05         74          57  27181
#
#    theta  alphaLow  alphaHigh  betaLow  betaHigh  gammaLow  gammaMid
# 0  93611      1696   16758377    21294     10503      8472     95355
# 1  93611      1696   16758377    21294     10503      8472     95355
# 2  93611      1696   16758377    21294     10503      8472     95355
# 3  93611      1696   16758377    21294     10503      8472     95355
# 4  93611      1696   16758377    21294     10503      8472     95355

# %%
#Cutting of starting and ending datapoints    
#Assumption : Data collected at regular interval
start_time = 15*60*(1000/100)
end_time = 35*60*(1000/100)
data = data.loc[start_time:end_time]

# %%
data.describe()
# Out:
#          timestampMs   eegRawValue  eegRawValueVolts     attention  \
# count   12001.000000  12001.000000      1.200100e+04  12001.000000
# mean   186592.981585    -18.417632     -4.046843e-06     73.567619
# std     42035.302031    148.500548      3.262952e-05     16.147341
# min    113668.000000  -1491.000000     -3.276123e-04     37.000000
# 25%    150410.000000     -4.000000     -8.789062e-07     61.000000
# 50%    186538.000000     35.000000      7.690430e-06     74.000000
# 75%    223109.000000     67.000000      1.472168e-05     87.000000
# max    259264.000000   1450.000000      3.186035e-04    100.000000
#
#          meditation         delta         theta      alphaLow     alphaHigh  \
# count  12001.000000  1.200100e+04  1.200100e+04  1.200100e+04  1.200100e+04
# mean      70.897342  2.237551e+06  4.741173e+06  2.825605e+06  3.380868e+06
# std       13.386522  5.301252e+06  7.489445e+06  6.257174e+06  6.709080e+06
# min       35.000000  7.230000e+02  5.586000e+03  1.570000e+02  1.109000e+03
# 25%       63.000000  2.063400e+04  2.045800e+04  7.135000e+03  8.567000e+03
# 50%       70.000000  1.525720e+05  7.061800e+04  1.523700e+04  1.653600e+04
# 75%       81.000000  6.897550e+05  1.674732e+07  2.730400e+04  3.068500e+04
# max       97.000000  1.677293e+07  1.677637e+07  1.677439e+07  1.677367e+07
#
#             betaLow      betaHigh      gammaLow      gammaMid
# count  1.200100e+04  1.200100e+04  1.200100e+04  1.200100e+04
# mean   1.418860e+06  4.584414e+05  4.723404e+05  2.978494e+05
# std    4.646090e+06  2.697172e+06  2.751222e+06  1.975002e+06
# min    9.950000e+02  6.840000e+02  7.520000e+02  2.460000e+03
# 25%    6.795000e+03  7.713000e+03  4.519000e+03  3.551400e+04
# 50%    1.131100e+04  1.132900e+04  6.923000e+03  7.287000e+04
# 75%    1.748600e+04  1.571200e+04  1.031000e+04  8.703600e+04
# max    1.677173e+07  1.676000e+07  1.676482e+07  1.677536e+07
